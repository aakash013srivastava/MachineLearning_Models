# %% [markdown]
# SIMPLE LINEAR REGRESSION MODEL 1 FOR PREDICTING SALARIES WITH AGE

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_excel('EmployeeSampleData.xlsx')
dataset=dataset[['Age','Annual Salary']].sample(20)
X = dataset.iloc[:, :1].values
y = dataset.iloc[:, -1].values

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title('Sal vs Exp(Training Set)')
plt.xlabel('YOE')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title('Sal vs Exp(Test Set)')
plt.xlabel('YOE')
plt.ylabel('Salary')
plt.show()

# %%
print(regressor.predict([[29]]))
# Out:
# [88441.03598887]
